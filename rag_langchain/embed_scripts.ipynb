# %%
import sys 
sys.path
# '' 表示当前目录
# Out:
# ['/home/baheas/.local/share/uv/python/cpython-3.12.13-linux-x86_64-gnu/lib/python312.zip',
#  '/home/baheas/.local/share/uv/python/cpython-3.12.13-linux-x86_64-gnu/lib/python3.12',
#  '/home/baheas/.local/share/uv/python/cpython-3.12-linux-x86_64-gnu/lib/python3.12/lib-dynload',
#  '',
#  '/home/baheas/wslcodespace/pipelines_rag/.venv/lib/python3.12/site-packages']

# %%
# from pathlib import Path

# # Path.cwd().parent 
# # # PosixPath('/home/baheas/wslcodespace/pipelines_rag')
# sys.path.append(str(Path.cwd().parent))

# %%
from pathlib import Path
import sys

proj_root = Path.cwd()
while not (proj_root / "pyproject.toml").exists():
    proj_root = proj_root.parent

if str(proj_root) not in sys.path:
    sys.path.insert(0, str(proj_root))

sys.path
# Out:
# ['/home/baheas/wslcodespace/pipelines_rag',
#  '/home/baheas/.local/share/uv/python/cpython-3.12.13-linux-x86_64-gnu/lib/python312.zip',
#  '/home/baheas/.local/share/uv/python/cpython-3.12.13-linux-x86_64-gnu/lib/python3.12',
#  '/home/baheas/.local/share/uv/python/cpython-3.12-linux-x86_64-gnu/lib/python3.12/lib-dynload',
#  '',
#  '/home/baheas/wslcodespace/pipelines_rag/.venv/lib/python3.12/site-packages']

# %%
from configs.config import settings

# if not settings.qwen3_embedding_06b_path:
#     raise ValueError("qwen3_embedding_06b_path is empty")

# if not settings.deepseek_api_key:
#     raise ValueError("deepseek_api_key is empty")

# if not settings.dashscope_api_key:
#     raise ValueError("dashscope_api_key is empty")  

assert settings.qwen3_embedding_06b_path, "qwen3_embedding_06b_path is empty"
assert settings.deepseek_api_key, "deepseek_api_key is empty"
assert settings.dashscope_api_key, "dashscope_api_key is empty"

embed_path = settings.qwen3_embedding_06b_path

embed_path
# Out:
# '/mnt/e/local_models/embedding/Qwen--Qwen3-Embedding-0.6B'

# %%
from langchain_huggingface import HuggingFaceEmbeddings 

embed_model = HuggingFaceEmbeddings(
    model_name=str(embed_path),
    model_kwargs={
        "device": "cpu",
        "local_files_only": True,
    },
    encode_kwargs={
        "normalize_embeddings": True,
    },
)
# Out:
# Loading weights:   0%|          | 0/310 [00:00<?, ?it/s]
