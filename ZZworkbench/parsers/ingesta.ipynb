# %%
from pydantic import BaseModel
from typing import Literal


class ImageType(BaseModel):
    image_type: Literal["screenshot", "table", "diagram", "chart", "image", "logo", "decorative", "other"]
    



ImageCaption_scheme = {
  "image_type": "screenshot | table | diagram | chart | logo | decorative | other",
  "evidence_role": "load_bearing | illustrative | noise | uncertain",
  "keep": True,
  "retrieval_caption": "详细描述，给检索和回答使用。包含 UI 标签、表格值、图中节点、箭头关系、关键数字。",
  "short_summary": "1-2 句话摘要，给 UI 和人工检查使用。",
  "transcribed_text": ["图中 OCR 到的关键文字"],
  "quality_flag": "ok | low_context | unreadable | likely_noise | needs_review",
  "confidence": 0.0
}
