# %%
from pathlib import Path 
from python_dotenv import load_env


env_file: Path = Path.cwd().parents[1]  / ".env"
assert env_file.is_file()
print(env_file)
# Out:
# /home/baheas/wslcodespace/pipelines_rag/.env

# %%
import vllm 
import mineru  # local 

from langchain_mineru import MineruLoader 

# > experiment: text-chunks 应该是什么样的？
# >1>文本知识库：text-chunks应该是什么样的，需要被解析的很清楚完整吗？ rag - pipeline是包含LLM推理的
# >2>embedding 是一个什么样的过程？以及embedding模型训练的数据是长什么样的？需要保证数据分布发生偏移吗？
